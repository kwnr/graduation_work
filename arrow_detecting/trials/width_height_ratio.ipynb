# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import detect_arrow

# %%
img=cv2.imread('/Users/hyeokbeom/Desktop/graduation_work/arrow_box.png')
arrow=detect_arrow.detect_arrow(img)[0]

# %%
cv2.drawContours(img,[arrow['approx'],arrow['parent']],-1,(0,0,255),3)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
box=arrow['parent']

# %%
w,h=box[3][0]-box[1][0]
h=-h

# %%
print(f"w{w},h{h}")
# Out:
# w1267,h771
